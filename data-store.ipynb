# %%
from rdflib import plugin
from rdflib.graph import Graph
from rdflib.store import Store
from rdflib_sqlalchemy import registerplugins
import sqlite3

# %%
registerplugins()

SQLALCHEMY_URL = "sqlite:///db/court_data.db"

store = plugin.get("SQLAlchemy", Store)(identifier="court_data_store")
graph = Graph(store, identifier="court_data_graph")
graph.open(SQLALCHEMY_URL, create=True)

graph.parse("./example-court-data.jsonld")
graph.close()

# %%
qres = g.query(query)
for row in qres:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In [4], line 2
#       1 g = rdflib.Graph()
# ----> 2 g.parse("http://danbri.org/foaf.rdf#")
#       4 knows_query = """
#       5 SELECT DISTINCT ?aname ?bname
#       6 WHERE {
#    (...)
#       9     ?b foaf:name ?bname .
#      10 }"""
#      12 qres = g.query(knows_query)
#
# File ~/.local/share/virtualenvs/triple-store-xOJM-nnj/lib/python3.10/site-packages/rdflib/graph.py:1306, in Graph.parse(self, source, publicID, format, location, file, data, **args)
#    1223 def parse(
#    1224     self,
#    1225     source: Optional[
#    (...)
#    1233     **args,
#    1234 ):
#    1235     """
#    1236     Parse an RDF source adding the resulting triples to the Graph.
#    1237
#    (...)
#    1303
#    1304     """
# -> 1306     source = create_input_source(
#    1307         source=source,
# ...
