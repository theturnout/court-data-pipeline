# %%
import scrapy
from scrapy.crawler import CrawlerProcess
from pyshacl import validate
import glob
import os
import regex as re
import json
import requests
import datetime
from rdflib import plugin
from rdflib.graph import Graph
from rdflib.store import Store
from rdflib_sqlalchemy import registerplugins
from sqlalchemy.orm import Session
from sqlalchemy.sql.expression import Insert
import sqlite3

# %% [markdown]
# ### Crawl Webpages and Scrape JSON-LD Information

# %%
### dev ###

# clear destination dir
files = glob.glob("/data/raw_json/*")
for file in files:
    os.remove(file)

# use local files
dev_sites = glob.glob("data/sites/*/*.html")

### /dev ###

# list of sites to scrape
sites = dev_sites
class JsonSpider(scrapy.Spider):
    
    """ 
    scrape .json-ld data from court websites.
    prefer linked .json, 
    scrape embedded data otherwise.
    """

    name = "court-data-spider"

    def start_requests(self):
          
        global sites
        
        # GET request, pass res to parse()
        for url in sites:
            yield scrapy.Request(url=f"http://localhost:8000/{url}", callback=self.parse)

            
    def parse(self, response):

        # look for json data. 
        linked_json = response.selector.xpath(
            '//link[@type="application/ld+json"]/@href').get()
        embedded_json = response.selector.xpath(
            '//script[@type="application/ld+json"]/text()').get()

        # use page source as filename, replace "/"
        # need a better convention
        page_source = response.url.replace("/", ".")
        filename = (page_source + ".json").replace(".html","")
  
        if linked_json is not None:
            # follow link to json file and grab data
            req = requests.get(linked_json)
            # to append source and date metadata below
            load_json = json.loads(req.content)        
        elif embedded_json is not None:
            # parse json data from html source
            # remove whitespace that is not in a value
            embedded_json = re.sub(r'\s+[^\:\S\"]', "", embedded_json)  
            # to append source and date metadata below
            load_json = json.loads(embedded_json[1:-1])
        else:
            return f"No valid JSON-LD data in {response.url}."

        # append source and date metadata
        load_json.append(
            {"source": response.url, "accessed": str(datetime.datetime.now())})

        # write json file
        json_out = json.dumps(load_json)
        with open(f"./data/raw_json/{filename}", "w") as output:
            output.write(json_out)

process = CrawlerProcess(
    # requests throttled due to limitations of python http.server
    settings = {
        "DOWNLOAD_DELAY": 1,
        "CONCURRENT_REQUESTS_PER_DOMAIN": 10
    }
)

process.crawl(JsonSpider)
process.start()
# Out:
# 2022-10-12 10:36:06 [scrapy.utils.log] INFO: Scrapy 2.6.3 started (bot: scrapybot)
# 2022-10-12 10:36:06 [scrapy.utils.log] INFO: Versions: lxml 4.9.1.0, libxml2 2.9.4, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.8.0, Python 3.10.2 (v3.10.2:a58ebcc701, Jan 13 2022, 14:50:16) [Clang 13.0.0 (clang-1300.0.29.30)], pyOpenSSL 22.1.0 (OpenSSL 3.0.5 5 Jul 2022), cryptography 38.0.1, Platform macOS-12.5.1-x86_64-i386-64bit
# 2022-10-12 10:36:06 [scrapy.crawler] INFO: Overridden settings:
# {'CONCURRENT_REQUESTS_PER_DOMAIN': 10, 'DOWNLOAD_DELAY': 1}
# 2022-10-12 10:36:06 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2022-10-12 10:36:06 [scrapy.extensions.telnet] INFO: Telnet Password: e8db8c176b733c11
# 2022-10-12 10:36:06 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2022-10-12 10:36:06 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2022-10-12 10:36:06 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2022-10-12 10:36:06 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2022-10-12 10:36:06 [scrapy.core.engine] INFO: Spider opened
# 2022-10-12 10:36:06 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2022-10-12 10:36:06 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2022-10-12 10:36:06 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/no-data/il-adams.html> (referer: None)
# 2022-10-12 10:36:07 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'str' in <GET http://localhost:8000/data/sites/no-data/il-adams.html>
# 2022-10-12 10:36:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/no-data/vt_chittenden.html> (referer: None)
# 2022-10-12 10:36:07 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'str' in <GET http://localhost:8000/data/sites/no-data/vt_chittenden.html>
# 2022-10-12 10:36:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/no-data/ca-alhambra.html> (referer: None)
# 2022-10-12 10:36:09 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'str' in <GET http://localhost:8000/data/sites/no-data/ca-alhambra.html>
# 2022-10-12 10:36:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/no-data/nm-bernalillo.html> (referer: None)
# 2022-10-12 10:36:10 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'str' in <GET http://localhost:8000/data/sites/no-data/nm-bernalillo.html>
# 2022-10-12 10:36:11 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/no-data/mi-flint.html> (referer: None)
# 2022-10-12 10:36:11 [scrapy.core.scraper] ERROR: Spider must return request, item, or None, got 'str' in <GET http://localhost:8000/data/sites/no-data/mi-flint.html>
# 2022-10-12 10:36:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/linked/il-adams.html> (referer: None)
# 2022-10-12 10:36:12 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): localhost:8000
# 2022-10-12 10:36:12 [urllib3.connectionpool] DEBUG: http://localhost:8000 "GET /data/valid-linked-data.json HTTP/1.1" 200 4757
# 2022-10-12 10:36:14 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/linked/vt_chittenden.html> (referer: None)
# 2022-10-12 10:36:14 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): localhost:8000
# 2022-10-12 10:36:14 [urllib3.connectionpool] DEBUG: http://localhost:8000 "GET /data/valid-linked-data.json HTTP/1.1" 200 4757
# 2022-10-12 10:36:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/linked/ca-alhambra.html> (referer: None)
# 2022-10-12 10:36:15 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): localhost:8000
# 2022-10-12 10:36:15 [urllib3.connectionpool] DEBUG: http://localhost:8000 "GET /data/valid-linked-data.json HTTP/1.1" 200 4757
# 2022-10-12 10:36:16 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/linked/nm-bernalillo.html> (referer: None)
# 2022-10-12 10:36:16 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): localhost:8000
# 2022-10-12 10:36:16 [urllib3.connectionpool] DEBUG: http://localhost:8000 "GET /data/valid-linked-data.json HTTP/1.1" 200 4757
# 2022-10-12 10:36:17 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/linked/mi-flint.html> (referer: None)
# 2022-10-12 10:36:17 [urllib3.connectionpool] DEBUG: Starting new HTTP connection (1): localhost:8000
# 2022-10-12 10:36:17 [urllib3.connectionpool] DEBUG: http://localhost:8000 "GET /data/valid-linked-data.json HTTP/1.1" 200 4757
# 2022-10-12 10:36:18 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/embedded/il-adams.html> (referer: None)
# 2022-10-12 10:36:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/embedded/vt_chittenden.html> (referer: None)
# 2022-10-12 10:36:21 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/embedded/ca-alhambra.html> (referer: None)
# 2022-10-12 10:36:22 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/embedded/nm-bernalillo.html> (referer: None)
# 2022-10-12 10:36:23 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://localhost:8000/data/sites/embedded/mi-flint.html> (referer: None)
# 2022-10-12 10:36:24 [scrapy.core.engine] INFO: Closing spider (finished)
# 2022-10-12 10:36:24 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 3654,
#  'downloader/request_count': 15,
#  'downloader/request_method_count/GET': 15,
#  'downloader/response_bytes': 6714303,
#  'downloader/response_count': 15,
#  'downloader/response_status_count/200': 15,
#  'elapsed_time_seconds': 17.175604,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2022, 10, 12, 17, 36, 24, 68145),
#  'log_count/DEBUG': 26,
#  'log_count/ERROR': 5,
#  'log_count/INFO': 10,
#  'memusage/max': 108228608,
#  'memusage/startup': 108224512,
#  'response_received_count': 15,
#  'scheduler/dequeued': 15,
#  'scheduler/dequeued/memory': 15,
#  'scheduler/enqueued': 15,
#  'scheduler/enqueued/memory': 15,
#  'start_time': datetime.datetime(2022, 10, 12, 17, 36, 6, 892541)}
# 2022-10-12 10:36:24 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ### Validate JSON-LD Files

# %%
### dev ### 

# clear destination dir
files = glob.glob("data/valid_json/*")
for file in files:
    os.remove(file)
    
### /dev ###

# scraped JSON-LD files 
scraped_json_files = glob.glob("data/raw_json/*")

# SHACL file to validate data against
shacl_file = 'data/defs/court-data-standard-shacl.ttl'

errors = []

def validate_json(scraped_json_files, shacl_file):
    """
    validate scraped json files
    if valid, move to valid_json folder
    if not, append error msg to errors
    """

    for file in scraped_json_files:
        if len(scraped_json_files) < 1:
            print("No files provided. Validation aborted.")
            break
        try:
            r = validate(file,
                         shacl_graph=shacl_file,
                         inference='none',
                         abort_on_first=True,
                         allow_infos=False,
                         allow_warnings=False,
                         meta_shacl=False,
                         advanced=True,
                         js=False,
                         debug=False)
            
            # if error, append msg to errors list
            if r[0] != True:
                msg = r[2]
                errors.append(f"{file}\n{msg}\n")
                print(f"{file} failed validation.")
            # otherwise, move file to valid_json folder
            else:
                renamed_file = str(file.split(".")[-2] + ".json")
                file.replace(".data/raw_json/","")
                os.rename(f"{file}", f"./data/valid_json/{renamed_file}")
                print(f"{file} successfully validated.")
                
        except json.JSONDecodeError:
            errors.append(f"{file}\nBad JSON format. Validation aborted.")
            pass
    
    print(*errors, sep="\n") if errors else print("All files successfully validated.")

validate_json(scraped_json_files, shacl_file)
# Out:
# 2022-10-12 10:36:25 [py.warnings] WARNING: /Users/home/.local/share/virtualenvs/court-data-pipeline-DL0ZJ-Cx/lib/python3.10/site-packages/pyshacl/constraints/core/string_based_constraints.py:279: FutureWarning: Possible nested set at position 64
#   re_matcher = re.compile(re_pattern, re_flags)
# data/raw_json/http:..localhost:8000.data.sites.embedded.il-adams.json successfully validated.
# data/raw_json/http:..localhost:8000.data.sites.linked.vt_chittenden.json successfully validated.
# data/raw_json/http:..localhost:8000.data.sites.embedded.nm-bernalillo.json successfully validated.
# data/raw_json/http:..localhost:8000.data.sites.linked.il-adams.json successfully validated.
# data/raw_json/http:..localhost:8000.data.sites.linked.nm-bernalillo.json successfully validated.
# data/raw_json/http:..localhost:8000.data.sites.linked.ca-alhambra.json successfully validated.
# data/raw_json/http:..localhost:8000.data.sites.embedded.mi-flint.json successfully validated.
# data/raw_json/http:..localhost:8000.data.sites.embedded.ca-alhambra.json successfully validated.
# data/raw_json/http:..localhost:8000.data.sites.embedded.vt_chittenden.json successfully validated.
# data/raw_json/http:..localhost:8000.data.sites.linked.mi-flint.json successfully validated.
# All files successfully validated.

# %% [markdown]
# ### Store JSON-LD Data in RDF... Store

# %%
### dev ###

db0 = "./data/db/court_data.db"
if os.path.exists(db0):
    os.remove(db0)
### dev ###    

valid_json_files = glob.glob("data/valid_json/*.json")
db =f"sqlite:///{db0}"

graph = Graph("SQLAlchemy", identifier='court_data')

graph.open(db, create=True)

for file in valid_json_files: 
    graph.parse(file, format="json-ld")

graph.commit()
result = graph.query("select * where {?s ?p ?o}")

for subject, predicate, object_ in result:
    print(subject, predicate, object_)

graph.close()
# Out:
# 2022-10-12 10:39:30 [rdflib.namespace] WARNING: caught a TypeError, retrying call to <class 'rdflib_sqlalchemy.store.SQLAlchemy'>.bind without override, see https://github.com/RDFLib/rdflib/issues/1880 for more info
# Traceback (most recent call last):
#   File "/Users/home/.local/share/virtualenvs/court-data-pipeline-DL0ZJ-Cx/lib/python3.10/site-packages/rdflib/namespace/__init__.py", line 627, in _store_bind
#     return self.store.bind(prefix, namespace, override=override)
# TypeError: SQLAlchemy.bind() got an unexpected keyword argument 'override'
# 2022-10-12 10:39:30 [rdflib.namespace] WARNING: caught a TypeError, retrying call to <class 'rdflib_sqlalchemy.store.SQLAlchemy'>.bind without override, see https://github.com/RDFLib/rdflib/issues/1880 for more info
# Traceback (most recent call last):
#   File "/Users/home/.local/share/virtualenvs/court-data-pipeline-DL0ZJ-Cx/lib/python3.10/site-packages/rdflib/namespace/__init__.py", line 627, in _store_bind
#     return self.store.bind(prefix, namespace, override=override)
# TypeError: SQLAlchemy.bind() got an unexpected keyword argument 'override'
# 2022-10-12 10:39:30 [rdflib.namespace] WARNING: caught a TypeError, retrying call to <class 'rdflib_sqlalchemy.store.SQLAlchemy'>.bind without override, see https://github.com/RDFLib/rdflib/issues/1880 for more info
# Traceback (most recent call last):
#   File "/Users/home/.local/share/virtualenvs/court-data-pipeline-DL0ZJ-Cx/lib/python3.10/site-packages/rdflib/namespace/__init__.py", line 627, in _store_bind
#     return self.store.bind(prefix, namespace, override=override)
# TypeError: SQLAlchemy.bind() got an unexpected keyword argument 'override'
# 2022-10-12 10:39:30 [rdflib.namespace] WARNING: caught a TypeError, retrying call to <class 'rdflib_sqlalchemy.store.SQLAlchemy'>.bind without override, see https://github.com/RDFLib/rdflib/issues/1880 for more info
# Traceback (most recent call last):
#   File "/Users/home/.local/share/virtualenvs/court-data-pipeline-DL0ZJ-Cx/lib/python3.10/site-packages/rdflib/namespace/__init__.py", line 627, in _store_bind
#     return self.store.bind(prefix, namespace, override=override)
# TypeError: SQLAlchemy.bind() got an unexpected keyword argument 'override'
# 2022-10-12 10:39:30 [rdflib.namespace] WARNING: caught a TypeError, retrying call to <class 'rdflib_sqlalchemy.store.SQLAlchemy'>.bind without override, see https://github.com/RDFLib/rdflib/issues/1880 for more info
# Traceback (most recent call last):
#   File "/Users/home/.local/share/virtualenvs/court-data-pipeline-DL0ZJ-Cx/lib/python3.10/site-packages/rdflib/namespace/__init__.py", line 627, in _store_bind
#     return self.store.bind(prefix, namespace, override=override)
# TypeError: SQLAlchemy.bind() got an unexpected keyword argument 'override'
# http://schema.org/name http://www.illinoiscourts.gov/Circuit State of Illinois Circuit Court
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type N17e84aaf6d3646e6aeeeea6f7991e5df http://schema.org/ContactPoint
# http://schema.org/address Ne6cb080e5fcb4732b78f634ac008b631 N7443f967df4d4364946c8cd35ba8b1d3
# http://schema.org/openingHoursSpecification Ne6cb080e5fcb4732b78f634ac008b631 Nfbdec82d44c84bc4a4e16d53cb0494c6
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type Ne6cb080e5fcb4732b78f634ac008b631 http://schema.org/Place
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type N7443f967df4d4364946c8cd35ba8b1d3 http://schema.org/PostalAddress
# http://schema.org/location http://www.illinoiscourts.gov/District1/CookCounty/Criminal Ne6cb080e5fcb4732b78f634ac008b631
# http://schema.org/streetAddress Nb1a13aff933a4696b75eb8e1677f19a5 521 Vermont Street
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type Nfbdec82d44c84bc4a4e16d53cb0494c6 http://schema.org/OpeningHoursSpecification
# http://schema.org/addressLocality Nb1a13aff933a4696b75eb8e1677f19a5 Quincy
# http://schema.org/addressRegion Nb1a13aff933a4696b75eb8e1677f19a5 IL
# http://schema.org/postalCode Nb1a13aff933a4696b75eb8e1677f19a5 62301
# http://schema.org/opens N446780043746411993e793c82b3a5125 09:30-08:00
# http://schema.org/closes N446780043746411993e793c82b3a5125 16:30-08:00
# http://schema.org/dayOfWeek N446780043746411993e793c82b3a5125 [Monday,Tuesday,Wednesday,Thursday,Friday]
# http://schema.org/hasMap N31da99804d1848e1811be6c6f2315869 http://www.illinoiscourts.gov/District1/CookCounty/map
# http://schema.org/contactType Ne157d1400dd44b4b96792a41e380f524 Clerk
# http://schema.org/description Ne157d1400dd44b4b96792a41e380f524 Click Clork
# http://schema.org/telephone Ne157d1400dd44b4b96792a41e380f524 (310) 578-9874
# http://schema.org/email Ne157d1400dd44b4b96792a41e380f524 clork.clirk@courts.gov
# http://schema.org/streetAddress N397c868df0904b17a0716108a46b43b7 521 Vermont Street
# http://schema.org/addressLocality N397c868df0904b17a0716108a46b43b7 Quincy
# http://schema.org/addressRegion N397c868df0904b17a0716108a46b43b7 IL
# http://schema.org/postalCode N397c868df0904b17a0716108a46b43b7 62301
# http://schema.org/opens N46ac0aac223c41d39141a1be5d9060c2 09:30-08:00
# http://schema.org/closes N46ac0aac223c41d39141a1be5d9060c2 16:30-08:00
# http://schema.org/dayOfWeek N46ac0aac223c41d39141a1be5d9060c2 [Monday,Tuesday,Wednesday,Thursday,Friday]
# http://schema.org/name http://www.illinoiscourts.gov/Circuit#Circuit2 State of Illinois Circuit 1
# http://schema.org/contactType N08fa6a209dcf41fc85a3e3fddd1cc59d Clerk
# http://schema.org/description N08fa6a209dcf41fc85a3e3fddd1cc59d Clark Clerk
# http://schema.org/telephone N08fa6a209dcf41fc85a3e3fddd1cc59d (310) 578-9874
# http://schema.org/email N08fa6a209dcf41fc85a3e3fddd1cc59d clerk.clark@courts.gov
# http://schema.org/itemListElement Nc6256c7f087042dea84ccce72f5a82e4 wifi, public restrooms
# http://schema.org/streetAddress N6eaa6f33ca0949b3ba93bd4510536d4c 521 Vermont Street
# http://schema.org/addressLocality N6eaa6f33ca0949b3ba93bd4510536d4c Quincy
# http://schema.org/addressRegion N6eaa6f33ca0949b3ba93bd4510536d4c IL
# http://schema.org/postalCode N6eaa6f33ca0949b3ba93bd4510536d4c 62301
# http://schema.org/opens Nd88ff34f56854a60b0367f59f55a8ec2 09:30-08:00
# http://schema.org/closes Nd88ff34f56854a60b0367f59f55a8ec2 16:30-08:00
# http://schema.org/dayOfWeek Nd88ff34f56854a60b0367f59f55a8ec2 [Monday,Tuesday,Wednesday,Thursday,Friday]
# http://schema.org/hasMap Na1c48a20dbed4294ba7e046dc9be03b6 http://www.illinoiscourts.gov/District1/CookCounty/map
# http://schema.org/contactType Nc44d677840554ffc8b28851a0f4a7151 Clerk
# http://schema.org/description Nc44d677840554ffc8b28851a0f4a7151 Click Clork
# http://schema.org/telephone Nc44d677840554ffc8b28851a0f4a7151 (310) 578-9874
# http://schema.org/email Nc44d677840554ffc8b28851a0f4a7151 clork.clirk@courts.gov
# http://schema.org/streetAddress Nd2981eb0a35242dda5882a00c87a5e00 521 Vermont Street
# http://schema.org/addressLocality Nd2981eb0a35242dda5882a00c87a5e00 Quincy
# http://schema.org/addressRegion Nd2981eb0a35242dda5882a00c87a5e00 IL
# http://schema.org/postalCode Nd2981eb0a35242dda5882a00c87a5e00 62301
# http://schema.org/opens N56285e5cb1634c238bc702cdf545d211 09:30-08:00
# http://schema.org/closes N56285e5cb1634c238bc702cdf545d211 16:30-08:00
# http://schema.org/dayOfWeek N56285e5cb1634c238bc702cdf545d211 [Monday,Tuesday,Wednesday,Thursday,Friday]
# http://schema.org/contactType N8b0bedbb65024585b7e596c6d22796d6 Clerk
# http://schema.org/description N8b0bedbb65024585b7e596c6d22796d6 Clark Clerk
# http://schema.org/telephone N8b0bedbb65024585b7e596c6d22796d6 (310) 578-9874
# http://schema.org/email N8b0bedbb65024585b7e596c6d22796d6 clerk.clark@courts.gov
# http://schema.org/itemListElement N16a304ef7701495eaabc959a77ebbd23 wifi, public restrooms
# http://schema.org/streetAddress Nb5fe155394ea4a86941aa1634ba2c9e1 521 Vermont Street
# http://schema.org/addressLocality Nb5fe155394ea4a86941aa1634ba2c9e1 Quincy
# http://schema.org/addressRegion Nb5fe155394ea4a86941aa1634ba2c9e1 IL
# http://schema.org/postalCode Nb5fe155394ea4a86941aa1634ba2c9e1 62301
# http://schema.org/opens N084651f927b84041aba1bc75c36e9d61 09:30-08:00
# http://schema.org/closes N084651f927b84041aba1bc75c36e9d61 16:30-08:00
# http://schema.org/dayOfWeek N084651f927b84041aba1bc75c36e9d61 [Monday,Tuesday,Wednesday,Thursday,Friday]
# http://schema.org/hasMap N547b3e80cc9642af990414dea0b0be7a http://www.illinoiscourts.gov/District1/CookCounty/map
# http://schema.org/contactType N47cf5127a535484e9ee46b81e5840926 Clerk
# http://schema.org/description N47cf5127a535484e9ee46b81e5840926 Click Clork
# http://schema.org/telephone N47cf5127a535484e9ee46b81e5840926 (310) 578-9874
# http://schema.org/email N47cf5127a535484e9ee46b81e5840926 clork.clirk@courts.gov
# http://schema.org/streetAddress N413573f0e61a4dad86a995ef09f77148 521 Vermont Street
# http://schema.org/addressLocality N413573f0e61a4dad86a995ef09f77148 Quincy
# http://schema.org/addressRegion N413573f0e61a4dad86a995ef09f77148 IL
# http://schema.org/postalCode N413573f0e61a4dad86a995ef09f77148 62301
# http://schema.org/opens N78e13ceccbea4dfc8a24717665b3644d 09:30-08:00
# http://schema.org/closes N78e13ceccbea4dfc8a24717665b3644d 16:30-08:00
# http://schema.org/dayOfWeek N78e13ceccbea4dfc8a24717665b3644d [Monday,Tuesday,Wednesday,Thursday,Friday]
# http://schema.org/contactType N67e1df0bd4d54b3e94ebaaa6b6b50eb8 Clerk
# http://schema.org/description N67e1df0bd4d54b3e94ebaaa6b6b50eb8 Clark Clerk
# http://schema.org/telephone N67e1df0bd4d54b3e94ebaaa6b6b50eb8 (310) 578-9874
# http://schema.org/email N67e1df0bd4d54b3e94ebaaa6b6b50eb8 clerk.clark@courts.gov
# http://schema.org/itemListElement N83ba728d398c4c68aae07254ff5b466c wifi, public restrooms
# http://schema.org/streetAddress N0f8a912865904b8aa99f1eb00d429c36 521 Vermont Street
# http://schema.org/addressLocality N0f8a912865904b8aa99f1eb00d429c36 Quincy
# http://schema.org/addressRegion N0f8a912865904b8aa99f1eb00d429c36 IL
# http://schema.org/postalCode N0f8a912865904b8aa99f1eb00d429c36 62301
# http://schema.org/opens N06f36ee09e414b7ebbd1e06606aa1afe 09:30-08:00
# http://schema.org/closes N06f36ee09e414b7ebbd1e06606aa1afe 16:30-08:00
# http://schema.org/dayOfWeek N06f36ee09e414b7ebbd1e06606aa1afe [Monday,Tuesday,Wednesday,Thursday,Friday]
# http://schema.org/hasMap Nb005733d2884496eb5c0dc08a4675322 http://www.illinoiscourts.gov/District1/CookCounty/map
# http://schema.org/contactType N17e84aaf6d3646e6aeeeea6f7991e5df Clerk
# http://schema.org/description N17e84aaf6d3646e6aeeeea6f7991e5df Click Clork
# http://schema.org/telephone N17e84aaf6d3646e6aeeeea6f7991e5df (310) 578-9874
# http://schema.org/email N17e84aaf6d3646e6aeeeea6f7991e5df clork.clirk@courts.gov
# http://schema.org/streetAddress N7443f967df4d4364946c8cd35ba8b1d3 521 Vermont Street
# http://schema.org/addressLocality N7443f967df4d4364946c8cd35ba8b1d3 Quincy
# http://schema.org/addressRegion N7443f967df4d4364946c8cd35ba8b1d3 IL
# http://schema.org/postalCode N7443f967df4d4364946c8cd35ba8b1d3 62301
# http://schema.org/opens Nfbdec82d44c84bc4a4e16d53cb0494c6 09:30-08:00
# http://schema.org/closes Nfbdec82d44c84bc4a4e16d53cb0494c6 16:30-08:00
# http://schema.org/dayOfWeek Nfbdec82d44c84bc4a4e16d53cb0494c6 [Monday,Tuesday,Wednesday,Thursday,Friday]

# %%
import csv

pages = "data/sites/*/*.html"
sites = []
for page in glob.glob(pages):
    sites.append([page])

  
with open("data/sites/websites.csv", "w", newline='') as f:
    write = csv.writer(f)
    write.writerows(sites)

sites = []
with open("data/sites/websites.csv", 'r') as f:
    reader = csv.reader(f)
    sites = [el for sub in list(reader) for el in sub]

print(sites)
